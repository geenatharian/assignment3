# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

# %%
data=pd.read_csv('/Users/geena.tharian/Downloads/StudentsPerformance.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33

# %% [markdown]
# # 1. Find out how many males and females participated in the test

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
data['average score']=(data['math score']+data['writing score']+data['reading score']/3)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
# 2  female        group B            some high school  free/reduced
# 3  female        group B                some college      standard
# 4  female        group C                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none           0             17             10
# 1                    none           8             24             23
# 2                    none          18             32             28
# 3                    none          11             38             32
# 4                    none          22             39             33
#
#    average score
# 0      15.666667
# 1      39.000000
# 2      56.666667
# 3      55.666667
# 4      68.000000

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# #1.It is observed from the above analysis, that students with high school as parental level of education have the lowest math, writing & reading score.
#
# #2.Only few Parents have master's degree.
#
# #3.Majority of the parents have some college degree.

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
data.groupby('gender')['math score','reading score','writing score'].mean()
# Out:
# /var/folders/j5/y57l9vp574g0szcfjxf1kxl40000gp/T/ipykernel_80109/1961774292.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('gender')['math score','reading score','writing score'].mean()
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %% [markdown]
# **Male students have higher average math score .
#
# **Female students have higher average reading & writing score .

# %%
data.groupby('test preparation course')['math score','reading score','writing score'].mean()
# Out:
# /var/folders/j5/y57l9vp574g0szcfjxf1kxl40000gp/T/ipykernel_80109/3190175430.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('test preparation course')['math score','reading score','writing score'].mean()
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
#  **Students who have completed the test preparation course score higher average marks for math, reading, and writing than those who don't complete the test preparation course.

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
math_var=stat.variance(data['math score'])
math_stdev=stat.stdev(data['math score'])
reading_var=stat.variance(data['reading score'])
reading_stdev=stat.stdev(data['reading score'])
writing_var=stat.variance(data['writing score'])
writing_stdev=stat.stdev(data['writing score'])

# %%
print(math_var,math_stdev)
# Out:
# 242.4114104104104 15.569566802272002

# %%
print(reading_var,reading_stdev)
# Out:
# 216.27925425425425 14.706435810700507

# %%
print(writing_var,writing_stdev)
# Out:
# 231.84268168168168 15.226381109169758

# %%
gender_var=data[['gender','math score','reading score','writing score']].groupby('gender').std()
gender_var
# Out:
#         math score  reading score  writing score
# gender
# female   16.029928      14.411018      14.844842
# male     14.556411      14.149594      14.227225

# %%
test_var=data[['test preparation course','math score','reading score','writing score']].groupby('test preparation course').std()
test_var
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 14.521847      13.537572      13.236412
# none                      15.705689      14.608896      15.041667

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this.

# %%
a=data.nlargest(250,['math score'])

# %%
a.head()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 515  female        group E                some college  standard
# 516  female        group E           bachelor's degree  standard
# 517  female        group E          associate's degree  standard
# 996    male        group A                some college  standard
# 997    male        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 515                    none         100             92             97
# 516                    none         100            100            100
# 517                    none         100            100            100
# 996               completed         100             96             86
# 997               completed         100             97             99

# %%
print(a.to_markdown())
# Out:
# |     | gender   | race/ethnicity   | parental level of education   | lunch        | test preparation course   |   math score |   reading score |   writing score |
# |----:|:---------|:-----------------|:------------------------------|:-------------|:--------------------------|-------------:|----------------:|----------------:|
# | 515 | female   | group E          | some college                  | standard     | none                      |          100 |              92 |              97 |
# | 516 | female   | group E          | bachelor's degree             | standard     | none                      |          100 |             100 |             100 |
# | 517 | female   | group E          | associate's degree            | standard     | none                      |          100 |             100 |             100 |
# | 996 | male     | group A          | some college                  | standard     | completed                 |          100 |              96 |              86 |
# ...
